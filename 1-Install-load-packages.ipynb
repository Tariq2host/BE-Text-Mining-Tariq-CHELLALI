# %% [markdown]
# # 2023-24
# ## Installation des packages utiles pour le BE

# %%
# !pip3 install papierstat
# !pip3 install pyquickhelper
# !pip3 install dbfread
# Avec une Erreur mais OK! : 
# !pip3 install pyensae
# !pip3 install textblob
# !pip3 install gensim
# !pip3 install python-Levenshtein

import pandas
import nltk
# Une seule fois :
nltk.download('wordnet')
nltk.download('words')
nltk.download('punkt')    
nltk.download('averaged_perceptron_tagger')
nltk.download('brown')
nltk.download('stopwords')
    
from nltk.corpus import stopwords
import string
from sklearn.metrics.pairwise import cosine_similarity
from nltk.stem import WordNetLemmatizer 
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from textblob import TextBlob, Word
from nltk.corpus import brown  # Il y a davantage de mots ici
# Out:
# Collecting papierstat
#   Downloading papierstat-0.2.408-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: scikit-learn>=0.21.0 in c:\users\tariq\anaconda3\lib\site-packages (from papierstat) (1.0.2)
# Requirement already satisfied: pandas in c:\users\tariq\anaconda3\lib\site-packages (from papierstat) (1.4.2)
# Collecting mlinsights (from papierstat)
#   Downloading mlinsights-0.5.0.tar.gz (1.7 MB)
#      ---------------------------------------- 1.7/1.7 MB 3.7 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: still running...
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: matplotlib in c:\users\tariq\anaconda3\lib\site-packages (from papierstat) (3.5.1)
# Collecting pandas-streaming (from papierstat)
#   Downloading pandas_streaming-0.5.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: numpy>=1.14.6 in c:\users\tariq\anaconda3\lib\site-packages (from scikit-learn>=0.21.0->papierstat) (1.21.5)
# Requirement already satisfied: scipy>=1.1.0 in c:\users\tariq\anaconda3\lib\site-packages (from scikit-learn>=0.21.0->papierstat) (1.7.3)
# Requirement already satisfied: joblib>=0.11 in c:\users\tariq\anaconda3\lib\site-packages (from scikit-learn>=0.21.0->papierstat) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\tariq\anaconda3\lib\site-packages (from scikit-learn>=0.21.0->papierstat) (2.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\tariq\anaconda3\lib\site-packages (from matplotlib->papierstat) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\tariq\anaconda3\lib\site-packages (from matplotlib->papierstat) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\tariq\anaconda3\lib\site-packages (from matplotlib->papierstat) (1.3.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\tariq\anaconda3\lib\site-packages (from matplotlib->papierstat) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\tariq\anaconda3\lib\site-packages (from matplotlib->papierstat) (9.0.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\tariq\appdata\roaming\python\python39\site-packages (from matplotlib->papierstat) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\tariq\anaconda3\lib\site-packages (from matplotlib->papierstat) (2.8.2)
# Collecting onnx>=1.14.0 (from mlinsights->papierstat)
#   Using cached onnx-1.15.0-cp39-cp39-win_amd64.whl.metadata (15 kB)
# Requirement already satisfied: pytz>=2020.1 in c:\users\tariq\anaconda3\lib\site-packages (from pandas->papierstat) (2021.3)
# Collecting protobuf>=3.20.2 (from onnx>=1.14.0->mlinsights->papierstat)
#   Using cached protobuf-4.25.3-cp39-cp39-win_amd64.whl.metadata (541 bytes)
# Requirement already satisfied: six>=1.5 in c:\users\tariq\appdata\roaming\python\python39\site-packages (from python-dateutil>=2.7->matplotlib->papierstat) (1.16.0)
# Downloading papierstat-0.2.408-py3-none-any.whl (1.9 MB)
#    ---------------------------------------- 1.9/1.9 MB 5.2 MB/s eta 0:00:00
# Downloading pandas_streaming-0.5.0-py3-none-any.whl (36 kB)
# Using cached onnx-1.15.0-cp39-cp39-win_amd64.whl (14.3 MB)
# Using cached protobuf-4.25.3-cp39-cp39-win_amd64.whl (413 kB)
# Building wheels for collected packages: mlinsights
#   Building wheel for mlinsights (pyproject.toml): started
#   Building wheel for mlinsights (pyproject.toml): finished with status 'error'
# Failed to build mlinsights
#   error: subprocess-exited-with-error
#
#   × Building wheel for mlinsights (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [311 lines of output]
#       -- setup: add extension mlinsights.mlmodel.direct_blas_lapack
#       -- setup: add extension mlinsights.mlmodel._piecewise_tree_regression_common
#       -- setup: add extension mlinsights.mlmodel.piecewise_tree_regression_criterion
#       -- setup: add extension mlinsights.mlmodel.piecewise_tree_regression_criterion_fast
#       -- setup: add extension mlinsights.mlmodel.piecewise_tree_regression_criterion_linear
#       -- setup: add extension mlinsights.mltree._tree_digitize
#       C:\Users\tariq\AppData\Local\Temp\pip-build-env-oz9ve3zq\overlay\Lib\site-packages\setuptools\config\_apply_pyprojecttoml.py:83: SetuptoolsWarning: `install_requires` overwritten in `pyproject.toml` (dependencies)
#         corresp(dist, value, root_dir)
#       running bdist_wheel
#       -- setup: option bdist_dir=build\bdist.win-amd64\wheel
#       -- setup: option build_lib=None
#       -- setup: option build_number=None
#       -- setup: option build_temp=None
#       -- setup: option compiler=None
#       -- setup: option compression=8
#       -- setup: option cuda_build=DEFAULT
#       -- setup: option cuda_link=STATIC
#       -- setup: option cuda_version=None
#       -- setup: option cython_c_in_temp=None
#       -- setup: option cython_compile_time_env=None
#       -- setup: option cython_cplus=None
#       -- setup: option cython_create_listing=None
#       -- setup: option cython_directives=None
#       -- setup: option cython_gdb=None
#       -- setup: option cython_gen_pxi=None
#       -- setup: option cython_include_dirs=None
#       -- setup: option cython_line_directives=None
#       -- setup: option debug=None
#       -- setup: option define=None
#       -- setup: option dist_dir=C:\Users\tariq\AppData\Local\Temp\pip-wheel-t_t611ik\.tmp-tqrdpr9l
#       -- setup: option force=None
#       -- setup: option group=None
#       -- setup: option include_dirs=None
#       -- setup: option inplace=None
#       -- setup: option keep_temp=False
#       -- setup: option libraries=None
#       -- setup: option library_dirs=None
#       -- setup: option link_objects=None
#       -- setup: option manylinux=False
#       -- setup: option ort_version=None
#       -- setup: option owner=None
#       -- setup: option parallel=None
#       -- setup: option plat_name=win-amd64
#       -- setup: option py_limited_api=False
#       -- setup: option python_tag=py3
#       -- setup: option relative=False
#       -- setup: option rpath=None
#       -- setup: option skip_build=0
#       -- setup: option swig_cpp=None
#       -- setup: option swig_opts=None
#       -- setup: option swig=None
#       -- setup: option undef=None
#       -- setup: option universal=False
#       -- setup: option use_cuda=True
#       -- setup: option use_nvtx=False
#       -- setup: option user=None
#       running build
#       running build_py
#       -- setup: option build_lib=build\lib.win-amd64-cpython-39
#       -- setup: option build_temp=None
#       -- setup: option compile=0
#       -- setup: option compiler=None
#       -- setup: option cuda_build=DEFAULT
#       -- setup: option cuda_link=STATIC
#       -- setup: option cuda_version=None
#       -- setup: option cython_c_in_temp=None
#       -- setup: option cython_compile_time_env=None
#       -- setup: option cython_cplus=None
#       -- setup: option cython_create_listing=None
#       -- setup: option cython_directives=None
#       -- setup: option cython_gdb=None
#       -- setup: option cython_gen_pxi=None
#       -- setup: option cython_include_dirs=None
#       -- setup: option cython_line_directives=None
#       -- setup: option debug=None
#       -- setup: option define=None
#       -- setup: option force=None
#       -- setup: option include_dirs=None
#       -- setup: option inplace=None
#       -- setup: option libraries=None
#       -- setup: option library_dirs=None
#       -- setup: option link_objects=None
#       -- setup: option manylinux=False
#       -- setup: option no_compile=None
#       -- setup: option optimize=0
#       -- setup: option ort_version=None
#       -- setup: option parallel=None
#       -- setup: option plat_name=None
#       -- setup: option rpath=None
#       -- setup: option swig_cpp=None
#       -- setup: option swig_opts=None
#       -- setup: option swig=None
#       -- setup: option undef=None
#       -- setup: option use_cuda=True
#       -- setup: option use_nvtx=False
#       -- setup: option user=None
#       creating build
#       creating build\lib.win-amd64-cpython-39
#       creating build\lib.win-amd64-cpython-39\mlinsights
#       copying mlinsights\ext_test_case.py -> build\lib.win-amd64-cpython-39\mlinsights
#       copying mlinsights\_config.py -> build\lib.win-amd64-cpython-39\mlinsights
#       copying mlinsights\__init__.py -> build\lib.win-amd64-cpython-39\mlinsights
#       creating build\lib.win-amd64-cpython-39\mlinsights\helpers
#       copying mlinsights\helpers\parameters.py -> build\lib.win-amd64-cpython-39\mlinsights\helpers
#       copying mlinsights\helpers\pipeline.py -> build\lib.win-amd64-cpython-39\mlinsights\helpers
#       copying mlinsights\helpers\__init__.py -> build\lib.win-amd64-cpython-39\mlinsights\helpers
#       creating build\lib.win-amd64-cpython-39\mlinsights\metrics
#       copying mlinsights\metrics\correlations.py -> build\lib.win-amd64-cpython-39\mlinsights\metrics
#       copying mlinsights\metrics\scoring_metrics.py -> build\lib.win-amd64-cpython-39\mlinsights\metrics
#       copying mlinsights\metrics\__init__.py -> build\lib.win-amd64-cpython-39\mlinsights\metrics
#       creating build\lib.win-amd64-cpython-39\mlinsights\mlbatch
#       copying mlinsights\mlbatch\cache_model.py -> build\lib.win-amd64-cpython-39\mlinsights\mlbatch
#       copying mlinsights\mlbatch\pipeline_cache.py -> build\lib.win-amd64-cpython-39\mlinsights\mlbatch
#       copying mlinsights\mlbatch\__init__.py -> build\lib.win-amd64-cpython-39\mlinsights\mlbatch
#       creating build\lib.win-amd64-cpython-39\mlinsights\mlmodel
#       copying mlinsights\mlmodel\anmf_predictor.py -> build\lib.win-amd64-cpython-39\mlinsights\mlmodel
#       copying mlinsights\mlmodel\categories_to_integers.py -> build\lib.win-amd64-cpython-39\mlinsights\mlmodel
#       copying mlinsights\mlmodel\classification_kmeans.py -> build\lib.win-amd64-cpython-39\mlinsights\mlmodel
#       copying mlinsights\mlmodel\decision_tree_logreg.py -> build\lib.win-amd64-cpython-39\mlinsights\mlmodel
#       copying mlinsights\mlmodel\extended_features.py -> build\lib.win-amd64-cpython-39\mlinsights\mlmodel
#       copying mlinsights\mlmodel\interval_regressor.py -> build\lib.win-amd64-cpython-39\mlinsights\mlmodel
#       copying mlinsights\mlmodel\kmeans_constraint.py -> build\lib.win-amd64-cpython-39\mlinsights\mlmodel
#       copying mlinsights\mlmodel\kmeans_l1.py -> build\lib.win-amd64-cpython-39\mlinsights\mlmodel
#       copying mlinsights\mlmodel\ml_featurizer.py -> build\lib.win-amd64-cpython-39\mlinsights\mlmodel
#       copying mlinsights\mlmodel\piecewise_estimator.py -> build\lib.win-amd64-cpython-39\mlinsights\mlmodel
#       copying mlinsights\mlmodel\piecewise_tree_regression.py -> build\lib.win-amd64-cpython-39\mlinsights\mlmodel
#       copying mlinsights\mlmodel\predictable_tsne.py -> build\lib.win-amd64-cpython-39\mlinsights\mlmodel
#       copying mlinsights\mlmodel\quantile_mlpregressor.py -> build\lib.win-amd64-cpython-39\mlinsights\mlmodel
#       copying mlinsights\mlmodel\quantile_regression.py -> build\lib.win-amd64-cpython-39\mlinsights\mlmodel
#       copying mlinsights\mlmodel\sklearn_testing.py -> build\lib.win-amd64-cpython-39\mlinsights\mlmodel
#       copying mlinsights\mlmodel\sklearn_text.py -> build\lib.win-amd64-cpython-39\mlinsights\mlmodel
#       copying mlinsights\mlmodel\sklearn_transform_inv.py -> build\lib.win-amd64-cpython-39\mlinsights\mlmodel
#       copying mlinsights\mlmodel\sklearn_transform_inv_fct.py -> build\lib.win-amd64-cpython-39\mlinsights\mlmodel
#       copying mlinsights\mlmodel\target_predictors.py -> build\lib.win-amd64-cpython-39\mlinsights\mlmodel
#       copying mlinsights\mlmodel\transfer_transformer.py -> build\lib.win-amd64-cpython-39\mlinsights\mlmodel
#       copying mlinsights\mlmodel\_extended_features_polynomial.py -> build\lib.win-amd64-cpython-39\mlinsights\mlmodel
#       copying mlinsights\mlmodel\_kmeans_022.py -> build\lib.win-amd64-cpython-39\mlinsights\mlmodel
#       copying mlinsights\mlmodel\_kmeans_constraint_.py -> build\lib.win-amd64-cpython-39\mlinsights\mlmodel
#       copying mlinsights\mlmodel\__init__.py -> build\lib.win-amd64-cpython-39\mlinsights\mlmodel
#       creating build\lib.win-amd64-cpython-39\mlinsights\mltree
#       copying mlinsights\mltree\tree_digitize.py -> build\lib.win-amd64-cpython-39\mlinsights\mltree
#       copying mlinsights\mltree\tree_structure.py -> build\lib.win-amd64-cpython-39\mlinsights\mltree
#       copying mlinsights\mltree\__init__.py -> build\lib.win-amd64-cpython-39\mlinsights\mltree
#       creating build\lib.win-amd64-cpython-39\mlinsights\plotting
#       copying mlinsights\plotting\gallery.py -> build\lib.win-amd64-cpython-39\mlinsights\plotting
#       copying mlinsights\plotting\visualize.py -> build\lib.win-amd64-cpython-39\mlinsights\plotting
#       copying mlinsights\plotting\__init__.py -> build\lib.win-amd64-cpython-39\mlinsights\plotting
#       creating build\lib.win-amd64-cpython-39\mlinsights\search_rank
#       copying mlinsights\search_rank\search_engine_predictions.py -> build\lib.win-amd64-cpython-39\mlinsights\search_rank
#       copying mlinsights\search_rank\search_engine_predictions_images.py -> build\lib.win-amd64-cpython-39\mlinsights\search_rank
#       copying mlinsights\search_rank\search_engine_vectors.py -> build\lib.win-amd64-cpython-39\mlinsights\search_rank
#       copying mlinsights\search_rank\__init__.py -> build\lib.win-amd64-cpython-39\mlinsights\search_rank
#       creating build\lib.win-amd64-cpython-39\mlinsights\sklapi
#       copying mlinsights\sklapi\sklearn_base.py -> build\lib.win-amd64-cpython-39\mlinsights\sklapi
#       copying mlinsights\sklapi\sklearn_base_classifier.py -> build\lib.win-amd64-cpython-39\mlinsights\sklapi
#       copying mlinsights\sklapi\sklearn_base_learner.py -> build\lib.win-amd64-cpython-39\mlinsights\sklapi
#       copying mlinsights\sklapi\sklearn_base_regressor.py -> build\lib.win-amd64-cpython-39\mlinsights\sklapi
#       copying mlinsights\sklapi\sklearn_base_transform.py -> build\lib.win-amd64-cpython-39\mlinsights\sklapi
#       copying mlinsights\sklapi\sklearn_base_transform_learner.py -> build\lib.win-amd64-cpython-39\mlinsights\sklapi
#       copying mlinsights\sklapi\sklearn_base_transform_stacking.py -> build\lib.win-amd64-cpython-39\mlinsights\sklapi
#       copying mlinsights\sklapi\sklearn_parameters.py -> build\lib.win-amd64-cpython-39\mlinsights\sklapi
#       copying mlinsights\sklapi\__init__.py -> build\lib.win-amd64-cpython-39\mlinsights\sklapi
#       creating build\lib.win-amd64-cpython-39\mlinsights\timeseries
#       copying mlinsights\timeseries\agg.py -> build\lib.win-amd64-cpython-39\mlinsights\timeseries
#       copying mlinsights\timeseries\ar.py -> build\lib.win-amd64-cpython-39\mlinsights\timeseries
#       copying mlinsights\timeseries\base.py -> build\lib.win-amd64-cpython-39\mlinsights\timeseries
#       copying mlinsights\timeseries\datasets.py -> build\lib.win-amd64-cpython-39\mlinsights\timeseries
#       copying mlinsights\timeseries\dummies.py -> build\lib.win-amd64-cpython-39\mlinsights\timeseries
#       copying mlinsights\timeseries\metrics.py -> build\lib.win-amd64-cpython-39\mlinsights\timeseries
#       copying mlinsights\timeseries\patterns.py -> build\lib.win-amd64-cpython-39\mlinsights\timeseries
#       copying mlinsights\timeseries\plotting.py -> build\lib.win-amd64-cpython-39\mlinsights\timeseries
#       copying mlinsights\timeseries\preprocessing.py -> build\lib.win-amd64-cpython-39\mlinsights\timeseries
#       copying mlinsights\timeseries\utils.py -> build\lib.win-amd64-cpython-39\mlinsights\timeseries
#       copying mlinsights\timeseries\__init__.py -> build\lib.win-amd64-cpython-39\mlinsights\timeseries
#       running egg_info
#       writing mlinsights.egg-info\PKG-INFO
#       writing dependency_links to mlinsights.egg-info\dependency_links.txt
#       writing requirements to mlinsights.egg-info\requires.txt
#       writing top-level names to mlinsights.egg-info\top_level.txt
#       -- setup: option build_lib=build\lib.win-amd64-cpython-39
#       -- setup: option build_temp=build\temp.win-amd64-cpython-39\Release
#       -- setup: option compiler=None
#       -- setup: option cuda_build=DEFAULT
#       -- setup: option cuda_link=STATIC
#       -- setup: option cuda_version=None
#       -- setup: option cython_c_in_temp=0
#       -- setup: option cython_compile_time_env=None
#       -- setup: option cython_cplus=0
#       -- setup: option cython_create_listing=0
#       -- setup: option cython_directives={}
#       -- setup: option cython_gdb=False
#       -- setup: option cython_gen_pxi=0
#       -- setup: option cython_include_dirs=[]
#       -- setup: option cython_line_directives=0
#       -- setup: option debug=None
#       -- setup: option define=None
#       -- setup: option force=None
#       -- setup: option include_dirs=['c:\\Users\\tariq\\anaconda3\\include', 'c:\\Users\\tariq\\anaconda3\\Include']
#       -- setup: option inplace=False
#       -- setup: option libraries=[]
#       -- setup: option library_dirs=['c:\\Users\\tariq\\anaconda3\\libs', 'c:\\Users\\tariq\\anaconda3', 'c:\\Users\\tariq\\anaconda3\\PCbuild\\amd64']
#       -- setup: option link_objects=None
#       -- setup: option manylinux=False
#       -- setup: option ort_version=None
#       -- setup: option parallel=None
#       -- setup: option plat_name=win-amd64
#       -- setup: option rpath=[]
#       -- setup: option swig_cpp=None
#       -- setup: option swig_opts=[]
#       -- setup: option swig=None
#       -- setup: option undef=None
#       -- setup: option use_cuda=True
#       -- setup: option use_nvtx=False
#       -- setup: option user=None
#       reading manifest file 'mlinsights.egg-info\SOURCES.txt'
#       reading manifest template 'MANIFEST.in'
#       warning: no files found matching '*.c' under directory 'mlinsights'
#       warning: no files found matching '*.h' under directory 'mlinsights'
#       warning: no files found matching '*.pxi' under directory 'mlinsights'
#       warning: no files found matching '_cmake' under directory 'mlinsights'
#       warning: no files found matching '*.cmake' under directory 'mlinsights'
#       warning: no files found matching '*.in' under directory 'mlinsights'
#       no previously-included directories found matching '_doc'
#       no previously-included directories found matching '_unittests'
#       warning: no previously-included files found matching '*.bat'
#       warning: no previously-included files found matching '*.yml'
#       warning: no previously-included files found matching '*.git*'
#       adding license file 'LICENSE.txt'
#       writing manifest file 'mlinsights.egg-info\SOURCES.txt'
#       copying mlinsights\mlmodel\_piecewise_tree_regression_common.cpp -> build\lib.win-amd64-cpython-39\mlinsights\mlmodel
#       copying mlinsights\mlmodel\_piecewise_tree_regression_common.cpython-310-x86_64-linux-gnu.so -> build\lib.win-amd64-cpython-39\mlinsights\mlmodel
#       copying mlinsights\mlmodel\_piecewise_tree_regression_common.pxd -> build\lib.win-amd64-cpython-39\mlinsights\mlmodel
#       copying mlinsights\mlmodel\_piecewise_tree_regression_common.pyx -> build\lib.win-amd64-cpython-39\mlinsights\mlmodel
#       copying mlinsights\mlmodel\direct_blas_lapack.cpp -> build\lib.win-amd64-cpython-39\mlinsights\mlmodel
#       copying mlinsights\mlmodel\direct_blas_lapack.cpython-310-x86_64-linux-gnu.so -> build\lib.win-amd64-cpython-39\mlinsights\mlmodel
#       copying mlinsights\mlmodel\direct_blas_lapack.pyx -> build\lib.win-amd64-cpython-39\mlinsights\mlmodel
#       copying mlinsights\mlmodel\piecewise_tree_regression_criterion.cpp -> build\lib.win-amd64-cpython-39\mlinsights\mlmodel
#       copying mlinsights\mlmodel\piecewise_tree_regression_criterion.cpython-310-x86_64-linux-gnu.so -> build\lib.win-amd64-cpython-39\mlinsights\mlmodel
#       copying mlinsights\mlmodel\piecewise_tree_regression_criterion.pyx -> build\lib.win-amd64-cpython-39\mlinsights\mlmodel
#       copying mlinsights\mlmodel\piecewise_tree_regression_criterion_fast.cpp -> build\lib.win-amd64-cpython-39\mlinsights\mlmodel
#       copying mlinsights\mlmodel\piecewise_tree_regression_criterion_fast.cpython-310-x86_64-linux-gnu.so -> build\lib.win-amd64-cpython-39\mlinsights\mlmodel
#       copying mlinsights\mlmodel\piecewise_tree_regression_criterion_fast.pyx -> build\lib.win-amd64-cpython-39\mlinsights\mlmodel
#       copying mlinsights\mlmodel\piecewise_tree_regression_criterion_linear.cpp -> build\lib.win-amd64-cpython-39\mlinsights\mlmodel
#       copying mlinsights\mlmodel\piecewise_tree_regression_criterion_linear.cpython-310-x86_64-linux-gnu.so -> build\lib.win-amd64-cpython-39\mlinsights\mlmodel
#       copying mlinsights\mlmodel\piecewise_tree_regression_criterion_linear.pyx -> build\lib.win-amd64-cpython-39\mlinsights\mlmodel
#       copying mlinsights\mltree\_tree_digitize.cpp -> build\lib.win-amd64-cpython-39\mlinsights\mltree
#       copying mlinsights\mltree\_tree_digitize.cpython-310-x86_64-linux-gnu.so -> build\lib.win-amd64-cpython-39\mlinsights\mltree
#       copying mlinsights\mltree\_tree_digitize.pyx -> build\lib.win-amd64-cpython-39\mlinsights\mltree
#       running build_ext
#       -- setup: version=sys.version_info(major=3, minor=9, micro=12, releaselevel='final', serial=0)
#       -- setup: cwd='C:\\Users\\tariq\\AppData\\Local\\Temp\\pip-install-3da9azyx\\mlinsights_08018f93bf2242e6af5a434c7432612b'
#       -- setup: source_path='C:\\Users\\tariq\\AppData\\Local\\Temp\\pip-install-3da9azyx\\mlinsights_08018f93bf2242e6af5a434c7432612b\\_cmake'
#       -- setup: build_path='C:\\Users\\tariq\\AppData\\Local\\Temp\\pip-install-3da9azyx\\mlinsights_08018f93bf2242e6af5a434c7432612b\\build\\temp.win-amd64-cpython-39\\Release'
#       -- setup: cmd=cmake -S C:\Users\tariq\AppData\Local\Temp\pip-install-3da9azyx\mlinsights_08018f93bf2242e6af5a434c7432612b\_cmake -B C:\Users\tariq\AppData\Local\Temp\pip-install-3da9azyx\mlinsights_08018f93bf2242e6af5a434c7432612b\build\temp.win-amd64-cpython-39\Release -DPYTHON_EXECUTABLE=c:\Users\tariq\anaconda3\python.exe -DCMAKE_BUILD_TYPE=Release -DPYTHON_VERSION=3.9.12 -DPYTHON_VERSION_MM=3.9 -DPYTHON_MODULE_EXTENSION=.cp39-win_amd64.pyd -DMLINSIGHTS_VERSION=0.5.0 -DPYTHON_MANYLINUX=0 -DUSE_CUDA=0 -DCUDA_BUILD=DEFAULT -DCUDA_LINK=STATIC -DPYTHON_INCLUDE_DIR=c:/Users/tariq/anaconda3/Include -DPYTHON_LIBRARY_DIR=c:/Users/tariq/anaconda3/Lib -DPYTHON_NUMPY_INCLUDE_DIR=C:/Users/tariq/AppData/Local/Temp/pip-build-env-oz9ve3zq/overlay/Lib/site-packages/numpy/core/include -DPYTHON_NUMPY_VERSION=1.26.4 -DSETUP_BUILD_PATH=C:\Users\tariq\AppData\Local\Temp\pip-install-3da9azyx\mlinsights_08018f93bf2242e6af5a434c7432612b\build\temp.win-amd64-cpython-39\Release -DSETUP_BUILD_LIB=C:\Users\tariq\AppData\Local\Temp\pip-install-3da9azyx\mlinsights_08018f93bf2242e6af5a434c7432612b\build\lib.win-amd64-cpython-39
#       CMake Error: The source directory "C:/Users/tariq/AppData/Local/Temp/pip-install-3da9azyx/mlinsights_08018f93bf2242e6af5a434c7432612b/_cmake" does not exist.
#       Specify --help for usage, or press the help button on the CMake GUI.
#       Traceback (most recent call last):
#         File "c:\Users\tariq\anaconda3\lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 353, in <module>
#           main()
#         File "c:\Users\tariq\anaconda3\lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 335, in main
#           json_out['return_val'] = hook(**hook_input['kwargs'])
#         File "c:\Users\tariq\anaconda3\lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 251, in build_wheel
#           return _build_backend().build_wheel(wheel_directory, config_settings,
#         File "C:\Users\tariq\AppData\Local\Temp\pip-build-env-oz9ve3zq\overlay\Lib\site-packages\setuptools\build_meta.py", line 410, in build_wheel
#           return self._build_with_temp_dir(
#         File "C:\Users\tariq\AppData\Local\Temp\pip-build-env-oz9ve3zq\overlay\Lib\site-packages\setuptools\build_meta.py", line 395, in _build_with_temp_dir
#           self.run_setup()
#         File "C:\Users\tariq\AppData\Local\Temp\pip-build-env-oz9ve3zq\overlay\Lib\site-packages\setuptools\build_meta.py", line 487, in run_setup
#           super().run_setup(setup_script=setup_script)
#         File "C:\Users\tariq\AppData\Local\Temp\pip-build-env-oz9ve3zq\overlay\Lib\site-packages\setuptools\build_meta.py", line 311, in run_setup
#           exec(code, locals())
#         File "<string>", line 671, in <module>
#         File "C:\Users\tariq\AppData\Local\Temp\pip-build-env-oz9ve3zq\overlay\Lib\site-packages\setuptools\__init__.py", line 103, in setup
#           return distutils.core.setup(**attrs)
#         File "C:\Users\tariq\AppData\Local\Temp\pip-build-env-oz9ve3zq\overlay\Lib\site-packages\setuptools\_distutils\core.py", line 185, in setup
#           return run_commands(dist)
#         File "C:\Users\tariq\AppData\Local\Temp\pip-build-env-oz9ve3zq\overlay\Lib\site-packages\setuptools\_distutils\core.py", line 201, in run_commands
#           dist.run_commands()
#         File "C:\Users\tariq\AppData\Local\Temp\pip-build-env-oz9ve3zq\overlay\Lib\site-packages\setuptools\_distutils\dist.py", line 969, in run_commands
#           self.run_command(cmd)
#         File "C:\Users\tariq\AppData\Local\Temp\pip-build-env-oz9ve3zq\overlay\Lib\site-packages\setuptools\dist.py", line 963, in run_command
#           super().run_command(command)
#         File "C:\Users\tariq\AppData\Local\Temp\pip-build-env-oz9ve3zq\overlay\Lib\site-packages\setuptools\_distutils\dist.py", line 988, in run_command
#           cmd_obj.run()
#         File "<string>", line 576, in run
#         File "C:\Users\tariq\AppData\Local\Temp\pip-build-env-oz9ve3zq\overlay\Lib\site-packages\wheel\bdist_wheel.py", line 368, in run
#           self.run_command("build")
#         File "C:\Users\tariq\AppData\Local\Temp\pip-build-env-oz9ve3zq\overlay\Lib\site-packages\setuptools\_distutils\cmd.py", line 318, in run_command
#           self.distribution.run_command(command)
#         File "C:\Users\tariq\AppData\Local\Temp\pip-build-env-oz9ve3zq\overlay\Lib\site-packages\setuptools\dist.py", line 963, in run_command
#           super().run_command(command)
#         File "C:\Users\tariq\AppData\Local\Temp\pip-build-env-oz9ve3zq\overlay\Lib\site-packages\setuptools\_distutils\dist.py", line 988, in run_command
#           cmd_obj.run()
#         File "C:\Users\tariq\AppData\Local\Temp\pip-build-env-oz9ve3zq\overlay\Lib\site-packages\setuptools\_distutils\command\build.py", line 131, in run
#           self.run_command(cmd_name)
#         File "C:\Users\tariq\AppData\Local\Temp\pip-build-env-oz9ve3zq\overlay\Lib\site-packages\setuptools\_distutils\cmd.py", line 318, in run_command
#           self.distribution.run_command(command)
#         File "C:\Users\tariq\AppData\Local\Temp\pip-build-env-oz9ve3zq\overlay\Lib\site-packages\setuptools\dist.py", line 963, in run_command
#           super().run_command(command)
#         File "C:\Users\tariq\AppData\Local\Temp\pip-build-env-oz9ve3zq\overlay\Lib\site-packages\setuptools\_distutils\dist.py", line 988, in run_command
#           cmd_obj.run()
#         File "<string>", line 541, in run
#         File "C:\Users\tariq\AppData\Local\Temp\pip-build-env-oz9ve3zq\overlay\Lib\site-packages\setuptools\command\build_ext.py", line 89, in run
#           _build_ext.run(self)
#         File "C:\Users\tariq\AppData\Local\Temp\pip-build-env-oz9ve3zq\overlay\Lib\site-packages\setuptools\_distutils\command\build_ext.py", line 345, in run
#           self.build_extensions()
#         File "<string>", line 544, in build_extensions
#         File "<string>", line 526, in run_cmake
#         File "<string>", line 459, in build_cmake
#         File "<string>", line 193, in _run_subprocess
#       RuntimeError: An error was found in the output. The build is stopped.
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for mlinsights
# ERROR: Could not build wheels for mlinsights, which is required to install pyproject.toml-based projects
# Collecting pyquickhelper
#   Downloading pyquickhelper-1.12.3823-py3-none-any.whl.metadata (8.7 kB)
# Collecting fire (from pyquickhelper)
#   Downloading fire-0.5.0.tar.gz (88 kB)
#      ---------------------------------------- 88.3/88.3 kB 1.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: numpy>=1.16.0 in c:\users\tariq\anaconda3\lib\site-packages (from pyquickhelper) (1.21.5)
# Collecting pyquicksetup>=0.2 (from pyquickhelper)
#   Downloading pyquicksetup-0.2.4.tar.gz (5.7 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: setuptools in c:\users\tariq\appdata\roaming\python\python39\site-packages (from pyquicksetup>=0.2->pyquickhelper) (65.6.3)
# Requirement already satisfied: six in c:\users\tariq\appdata\roaming\python\python39\site-packages (from fire->pyquickhelper) (1.16.0)
# Requirement already satisfied: termcolor in c:\users\tariq\appdata\roaming\python\python39\site-packages (from fire->pyquickhelper) (2.1.1)
# Downloading pyquickhelper-1.12.3823-py3-none-any.whl (3.3 MB)
#    ---------------------------------------- 3.3/3.3 MB 4.6 MB/s eta 0:00:00
# Building wheels for collected packages: pyquicksetup, fire
#   Building wheel for pyquicksetup (setup.py): started
#   Building wheel for pyquicksetup (setup.py): finished with status 'done'
#   Created wheel for pyquicksetup: filename=pyquicksetup-0.2.4-py3-none-any.whl size=6724 sha256=dba3183cdedf20672a85acf6e33d26f79e26938ccd09ea481a7f8158d666ca92
#   Stored in directory: c:\users\tariq\appdata\local\pip\cache\wheels\29\8d\eb\89cf8763cc12efe122194a701890ffa8fa6a13860c43f749f1
#   Building wheel for fire (setup.py): started
#   Building wheel for fire (setup.py): finished with status 'done'
#   Created wheel for fire: filename=fire-0.5.0-py2.py3-none-any.whl size=116947 sha256=eca4b276fd1e0f839f612f78d0cc0ed48c4cdb09896f71b1162f348bc258cb27
#   Stored in directory: c:\users\tariq\appdata\local\pip\cache\wheels\f7\f1\89\b9ea2bf8f80ec027a88fef1d354b3816b4d3d29530988972f6
# Successfully built pyquicksetup fire
# Installing collected packages: pyquicksetup, fire, pyquickhelper
# Successfully installed fire-0.5.0 pyquickhelper-1.12.3823 pyquicksetup-0.2.4
# Collecting dbfread
#   Downloading dbfread-2.0.7-py2.py3-none-any.whl.metadata (3.3 kB)
# Downloading dbfread-2.0.7-py2.py3-none-any.whl (20 kB)
# Installing collected packages: dbfread
# Successfully installed dbfread-2.0.7
# Collecting pyensae
#   Downloading pyensae-1.3.967-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: pyquickhelper>=1.8 in c:\users\tariq\anaconda3\lib\site-packages (from pyensae) (1.12.3823)
# Requirement already satisfied: numpy>=1.18 in c:\users\tariq\anaconda3\lib\site-packages (from pyensae) (1.21.5)
# Requirement already satisfied: pandas>=1.0 in c:\users\tariq\anaconda3\lib\site-packages (from pyensae) (1.4.2)
# Requirement already satisfied: matplotlib>=3.0 in c:\users\tariq\anaconda3\lib\site-packages (from pyensae) (3.5.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\tariq\anaconda3\lib\site-packages (from matplotlib>=3.0->pyensae) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\tariq\anaconda3\lib\site-packages (from matplotlib>=3.0->pyensae) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\tariq\anaconda3\lib\site-packages (from matplotlib>=3.0->pyensae) (1.3.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\tariq\anaconda3\lib\site-packages (from matplotlib>=3.0->pyensae) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\tariq\anaconda3\lib\site-packages (from matplotlib>=3.0->pyensae) (9.0.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\tariq\appdata\roaming\python\python39\site-packages (from matplotlib>=3.0->pyensae) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\tariq\anaconda3\lib\site-packages (from matplotlib>=3.0->pyensae) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\tariq\anaconda3\lib\site-packages (from pandas>=1.0->pyensae) (2021.3)
# Requirement already satisfied: fire in c:\users\tariq\anaconda3\lib\site-packages (from pyquickhelper>=1.8->pyensae) (0.5.0)
# Requirement already satisfied: pyquicksetup>=0.2 in c:\users\tariq\anaconda3\lib\site-packages (from pyquickhelper>=1.8->pyensae) (0.2.4)
# Requirement already satisfied: setuptools in c:\users\tariq\appdata\roaming\python\python39\site-packages (from pyquicksetup>=0.2->pyquickhelper>=1.8->pyensae) (65.6.3)
# Requirement already satisfied: six>=1.5 in c:\users\tariq\appdata\roaming\python\python39\site-packages (from python-dateutil>=2.7->matplotlib>=3.0->pyensae) (1.16.0)
# Requirement already satisfied: termcolor in c:\users\tariq\appdata\roaming\python\python39\site-packages (from fire->pyquickhelper>=1.8->pyensae) (2.1.1)
# Downloading pyensae-1.3.967-py3-none-any.whl (493 kB)
#    ---------------------------------------- 493.1/493.1 kB 3.1 MB/s eta 0:00:00
# Installing collected packages: pyensae
# Successfully installed pyensae-1.3.967
# Collecting textblob
#   Downloading textblob-0.18.0.post0-py3-none-any.whl.metadata (4.5 kB)
# Collecting nltk>=3.8 (from textblob)
#   Downloading nltk-3.8.1-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: click in c:\users\tariq\anaconda3\lib\site-packages (from nltk>=3.8->textblob) (8.0.4)
# Requirement already satisfied: joblib in c:\users\tariq\anaconda3\lib\site-packages (from nltk>=3.8->textblob) (1.1.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\tariq\anaconda3\lib\site-packages (from nltk>=3.8->textblob) (2022.3.15)
# Requirement already satisfied: tqdm in c:\users\tariq\anaconda3\lib\site-packages (from nltk>=3.8->textblob) (4.64.0)
# Requirement already satisfied: colorama in c:\users\tariq\anaconda3\lib\site-packages (from click->nltk>=3.8->textblob) (0.4.4)
# Downloading textblob-0.18.0.post0-py3-none-any.whl (626 kB)
#    ---------------------------------------- 626.3/626.3 kB 2.6 MB/s eta 0:00:00
# Downloading nltk-3.8.1-py3-none-any.whl (1.5 MB)
#    ---------------------------------------- 1.5/1.5 MB 4.4 MB/s eta 0:00:00
# Installing collected packages: nltk, textblob
#   Attempting uninstall: nltk
#     Found existing installation: nltk 3.7
#     Uninstalling nltk-3.7:
#       Successfully uninstalled nltk-3.7
# Successfully installed nltk-3.8.1 textblob-0.18.0.post0
# Requirement already satisfied: gensim in c:\users\tariq\anaconda3\lib\site-packages (4.1.2)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\tariq\anaconda3\lib\site-packages (from gensim) (1.21.5)
# Requirement already satisfied: scipy>=0.18.1 in c:\users\tariq\anaconda3\lib\site-packages (from gensim) (1.7.3)
# Requirement already satisfied: smart-open>=1.8.1 in c:\users\tariq\anaconda3\lib\site-packages (from gensim) (5.1.0)
# Collecting python-Levenshtein
#   Downloading python_Levenshtein-0.25.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting Levenshtein==0.25.0 (from python-Levenshtein)
#   Downloading Levenshtein-0.25.0-cp39-cp39-win_amd64.whl.metadata (3.4 kB)
# Collecting rapidfuzz<4.0.0,>=3.1.0 (from Levenshtein==0.25.0->python-Levenshtein)
#   Downloading rapidfuzz-3.6.2-cp39-cp39-win_amd64.whl.metadata (11 kB)
# Downloading python_Levenshtein-0.25.0-py3-none-any.whl (9.4 kB)
# Downloading Levenshtein-0.25.0-cp39-cp39-win_amd64.whl (98 kB)
#    ---------------------------------------- 98.6/98.6 kB 1.9 MB/s eta 0:00:00
# Downloading rapidfuzz-3.6.2-cp39-cp39-win_amd64.whl (1.6 MB)
#    ---------------------------------------- 1.6/1.6 MB 3.7 MB/s eta 0:00:00
# Installing collected packages: rapidfuzz, Levenshtein, python-Levenshtein
# Successfully installed Levenshtein-0.25.0 python-Levenshtein-0.25.0 rapidfuzz-3.6.2
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\tariq\AppData\Roaming\nltk_data...
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\tariq\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\words.zip.
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\tariq\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\tariq\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package brown to
# [nltk_data]     C:\Users\tariq\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\brown.zip.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\tariq\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
